# %% [markdown]
# # Inicialização

# %%
# Necessary imports
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

import missingno as msno
import gc

from ast import literal_eval

style.use('bmh')

# %matplotlib inline

# %%
acq_train = pd.read_csv('data/acquisition_train.csv')
acq_test = pd.read_csv('data/acquisition_test.csv')
spend_train = pd.read_csv('data/spend_train.csv')

# %%
acq_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 43 columns):
# ids                                                 45000 non-null object
# target_default                                      41741 non-null object
# score_1                                             44438 non-null object
# score_2                                             44438 non-null object
# score_3                                             44438 non-null float64
# score_4                                             45000 non-null float64
# score_5                                             45000 non-null float64
# score_6                                             45000 non-null float64
# risk_rate                                           44438 non-null float64
# last_amount_borrowed                                15044 non-null float64
# last_borrowed_in_months                             15044 non-null float64
# credit_limit                                        31200 non-null float64
# reason                                              44434 non-null object
# income                                              44438 non-null float64
# facebook_profile                                    40542 non-null object
# state                                               44438 non-null object
# zip                                                 44438 non-null object
# channel                                             44438 non-null object
# job_name                                            41664 non-null object
# real_state                                          44438 non-null object
# ok_since                                            18455 non-null float64
# n_bankruptcies                                      44303 non-null float64
# n_defaulted_loans                                   44426 non-null float64
# n_accounts                                          44438 non-null float64
# n_issues                                            33456 non-null float64
# application_time_applied                            45000 non-null object
# application_time_in_funnel                          45000 non-null int64
# email                                               45000 non-null object
# external_data_provider_credit_checks_last_2_year    22372 non-null float64
# external_data_provider_credit_checks_last_month     45000 non-null int64
# external_data_provider_credit_checks_last_year      29876 non-null float64
# external_data_provider_email_seen_before            42767 non-null float64
# external_data_provider_first_name                   45000 non-null object
# external_data_provider_fraud_score                  45000 non-null int64
# lat_lon                                             43637 non-null object
# marketing_channel                                   41422 non-null object
# profile_phone_number                                45000 non-null object
# reported_income                                     45000 non-null float64
# shipping_state                                      45000 non-null object
# shipping_zip_code                                   45000 non-null int64
# profile_tags                                        45000 non-null object
# user_agent                                          44278 non-null object
# target_fraud                                        1522 non-null object
# dtypes: float64(18), int64(4), object(21)
# memory usage: 14.8+ MB

# %%
spend_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980818 entries, 0 to 980817
# Data columns (total 7 columns):
# ids                  980818 non-null object
# credit_line          980818 non-null int64
# month                980818 non-null int64
# spends               980818 non-null float64
# revolving_balance    980818 non-null float64
# card_request         980818 non-null int64
# minutes_cs           980818 non-null float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 52.4+ MB

# %% [markdown]
# Já aqui podemos observar que `spend_train`  não possui *missing values*. Vamos analisar a distribuição dos `ids` em nos arquivos de gastos e de fraude/inadimplência.

# %%
spend_ids = set(spend_train['ids'].values.tolist())
acq_ids = set(acq_train['ids'].values.tolist())

print('Número de ids em spend: {:d}'.format(len(spend_ids)))
print('Número de ids em acq: {:d}'.format(len(acq_ids)))
print('Número de ids na interseção: {:d}'.format(len(acq_ids.intersection(spend_ids))))
# Out:
# Número de ids em spend: 45000
# Número de ids em acq: 45000
# Número de ids na interseção: 45000

# %% [markdown]
# Cada um possui 45000 ids, e a interseção de ambos conjuntos tem o mesmo número.
# Logo, a tabela de gastos possui registro para todos clientes na tabela de aquisição.
#
# Vejamos a descrição do conjunto de aquisição.

# %%
acq_train.describe()
# Out:
#             score_3       score_4       score_5       score_6     risk_rate  \
# count  44438.000000  45000.000000  45000.000000  45000.000000  44438.000000
# mean     347.983258    100.006797      0.500037     99.925228      0.296717
# std      110.429165      3.178080      0.288326     10.016549      0.101933
# min        0.000000     86.191572      0.000035     60.663039      0.000000
# 25%      270.000000     97.867036      0.252150     93.198353      0.220000
# 50%      340.000000    100.018900      0.500753     99.974796      0.290000
# 75%      420.000000    102.141797      0.748816    106.640275      0.360000
# max      990.000000    113.978234      0.999973    142.192400      0.900000
#
#        last_amount_borrowed  last_borrowed_in_months   credit_limit  \
# count          15044.000000             15044.000000   31200.000000
# mean           13782.341991                41.763893   34381.951154
# std             8077.571933                10.252705   36586.982218
# min             1005.180000                36.000000       0.000000
# 25%             7519.502500                36.000000   10000.000000
# 50%            12023.465000                36.000000   25647.000000
# 75%            19220.270000                36.000000   47086.750000
# max            35059.600000                60.000000  448269.000000
#
#              income      ok_since        ...            n_accounts  \
# count  4.443800e+04  18455.000000        ...          44438.000000
# mean   7.160739e+04     35.069737        ...             10.696701
# std    5.185897e+04     21.663194        ...              4.592463
# min    4.821180e+03      0.000000        ...              0.000000
# 25%    4.501078e+04     17.000000        ...              7.000000
# 50%    6.126676e+04     32.000000        ...             10.000000
# 75%    8.601923e+04     50.000000        ...             13.000000
# max    5.000028e+06    141.000000        ...             49.000000
#
#            n_issues  application_time_in_funnel  \
# count  33456.000000                45000.000000
# mean      11.068119                  247.537000
# std        4.595501                  146.118398
# min        0.000000                    0.000000
# 25%        8.000000                  120.000000
# 50%       10.000000                  248.000000
# 75%       14.000000                  375.000000
# max       49.000000                  500.000000
#
#        external_data_provider_credit_checks_last_2_year  \
# count                                           22372.0
# mean                                                0.0
# std                                                 0.0
# min                                                 0.0
# 25%                                                 0.0
# 50%                                                 0.0
# 75%                                                 0.0
# max                                                 0.0
#
#        external_data_provider_credit_checks_last_month  \
# count                                     45000.000000
# mean                                          1.501067
# std                                           1.114941
# min                                           0.000000
# 25%                                           1.000000
# 50%                                           2.000000
# 75%                                           2.000000
# max                                           3.000000
#
#        external_data_provider_credit_checks_last_year  \
# count                                    29876.000000
# mean                                         0.503381
# std                                          0.499997
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        external_data_provider_email_seen_before  \
# count                              42767.000000
# mean                                  12.534781
# std                                  126.530487
# min                                 -999.000000
# 25%                                   11.000000
# 50%                                   27.000000
# 75%                                   43.000000
# max                                   59.000000
#
#        external_data_provider_fraud_score  reported_income  shipping_zip_code
# count                        45000.000000     4.500000e+04       45000.000000
# mean                           500.399800              inf       33923.514844
# std                            287.968873              NaN       12692.406382
# min                              0.000000     4.030000e+02       12001.000000
# 25%                            252.000000     5.094825e+04       22937.000000
# 50%                            503.000000     1.017790e+05       33896.000000
# 75%                            747.000000     1.513372e+05       44910.000000
# max                           1000.000000              inf       56000.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ## Manipulação de dados
#
# Fazemos a seguir uma manipulação simples dos dados, de modo a faciliar a análise exploratória a seguir:
# * Criamos uma váriavel binária para indicar os valores conhecidos de fraude
# * Fazemos o *parsing* do horário de *application*, e guardamos apenas a hora do dia
# * Fazemos o *parsing* de `lat_lon` em duas novas colunas
# * Eliminamos a coluna de primeiro nome e telefones, pois não devem influenciar casos de fraude ou inadimplência (Telefones duplicados poderiam ser indicativo de fraude, mas não há duplicações)
# * Criamos listas para ajudar a discernir os diferentes tipos de variáveis

# %%
acq_train['target_fraud_bin'] = acq_train['target_fraud'].apply(lambda x : False if pd.isna(x) else True)

# %%
parse_time_hour = lambda x: x.split(':')[0]

acq_train['application_hour_applied'] = pd.to_numeric(acq_train['application_time_applied'].apply(parse_time_hour)).replace(24,0)
acq_train.drop('application_time_applied',inplace=True, axis=1)

acq_test['application_hour_applied'] = pd.to_numeric(acq_test['application_time_applied'].apply(parse_time_hour)).replace(24,0)
acq_test.drop('application_time_applied',inplace=True, axis=1)

# %%
def lat_lon_parse (df):
    df['lat_lon'] = df['lat_lon'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    df[['lat','lon']] = df['lat_lon'].apply(pd.Series)
    df.drop('lat_lon', inplace=True, axis=1)
    
lat_lon_parse(acq_train)
lat_lon_parse(acq_test)

# %%
acq_train.drop('external_data_provider_first_name',inplace=True,axis=1)
acq_test.drop('external_data_provider_first_name',inplace=True,axis=1)

# %%
category = ['ids',
 'score_1',
 'score_2',
 'profile_tags',
 'shipping_zip_code',
 'reason',
 'state',
 'zip',
 'channel',
 'job_name',
 'real_state',
 'target_fraud',
 'user_agent',
 'email',
 'shipping_state',
 'marketing_channel'
]

binary = ['target_default',     
         'target_fraud_bin',
         'facebook_profile'
         ]

discrete = ['last_borrowed_in_months',
 'application_hour_applied',
  'ok_since',
 'n_bankruptcies',
 'n_defaulted_loans',
 'n_accounts',
 'n_issues',
 'external_data_provider_credit_checks_last_2_year',
 'external_data_provider_credit_checks_last_month',
 'external_data_provider_credit_checks_last_year',
  'external_data_provider_email_seen_before'
]

continuous = ['score_3',
 'score_4',
 'score_5',
 'score_6',
 'risk_rate',
 'last_amount_borrowed',
 'application_time_in_funnel',
 'credit_limit',
 'income',
 'reported_income',    
 'external_data_provider_fraud_score',
 'lat',
 'lon']

for c in category:
    acq_train[c].astype('category')

# %%
# Ajustar valores de income
acq_train.replace(np.inf,np.nan, inplace=True)
acq_test.replace(np.inf,np.nan, inplace=True)

# %%
# Fix email typos

def clean_replace(df, replace_dict):
    for key in replace_dict:
        for entry in replace_dict[key]:
            df[key].replace(entry[0],entry[1],inplace=True)

replace_dict = {}
replace_dict['email'] = [['gmaill.com','gmail.com'],['hotmaill.com','hotmail.com']]

clean_replace(acq_train,replace_dict)
clean_replace(acq_test,replace_dict)

# %% [markdown]
# # Exploração de dados

# %% [markdown]
# Nesta seção, faremos uma análise geral dos dados fornecidos, a fim de obter *insights* para a modelagem.

# %% [markdown]
# ## Análise de inadimplência e fraude

# %% [markdown]
# Analisaremos a seguir as distribuições de inadimplência e fraude no conjunto de dados.

# %%
plt.figure(figsize=(6,5))
#plt.grid()
plt.title('Inadimplência')

ax = sns.countplot('target_default',data=acq_train)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(100*p.get_height()/len(acq_train['target_default'])), (p.get_x()+ 0.3, p.get_height()+100))

# %%
sum(acq_train['target_default'].isna())/len(acq_train['target_default'])*100
# Out:
# 7.242222222222222

# %% [markdown]
# Podemos observar que a base é altamente enviesada com relação à inadimplência - quase 78% de todos os registros são clientes adimplentes. Precisaremos levar isto em conta depois, ao criar um modelo de predição.
# Note ainda, que cerca de 7% dos valores estão faltando no alvo adimplência.
#
# Analisamos agora a o alvo fraude.

# %%
plt.figure(figsize=(6,5))
#plt.grid()
plt.title('Fraude')

ax = sns.countplot('target_fraud',data=acq_train)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(100*p.get_height()/len(acq_train['target_fraud'])), (p.get_x()+ 0.3, p.get_height()+10))

# %% [markdown]
# Observamos do gráfico acima que cerca de 2% dos fraudadores na base de dados são da classe 'amigos ou parentes'; e 1.37% se encaixam nos demais tipos de fraude. É importante notar que os dois somam menos que 4% do total, o que significa que a vasta maioria das observações não possui uma informação com relação a fraude. Isso pode ocorrer em dois casos: ou a pessoa não é fraudadora, ou ainda não sabemos que ela o é.
#
# Para fins de análise, vamos dar o benefício da dúvida àqueles que não possuem nenhuma informação sobre fraude e considerá-los isentos. Assim, a variável `target_fraud_bin` se torna o alvo para predição de fraude.

# %% [markdown]
# Dentre os fraudadores marcados como 'amigos ou família', há uma grande diferença entre adimplentes e inadimplentes, com uma propensão à inadimplência, como mostra o gráfico a seguir. Dentre os demais fraudadores, os números são quase os mesmos.

# %%
sns.catplot(x="target_default", kind="count",
            col="target_fraud", data=acq_train,
            height=5, aspect=.8)

# %% [markdown]
# ### Estado de envio

# %% [markdown]
# Observando os estados de envio, apenas três estados possuem um maior número de fraudadores não marcados como 'amigos e família': MT, PB e PA.

# %%
plt.figure(figsize=(10,7))
#plt.grid()
plt.title('Fraude')
sns.countplot(y="shipping_state", hue="target_fraud", data=acq_train)

# %% [markdown]
# ### Mapa

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-75, -35, -35, 5], crs=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
#ax.add_feature(cfeature.RIVERS)


# 2. scatter city data, with color reflecting population
# and size reflecting area
ax.scatter(acq_train['lon'], 
            acq_train['lat'],
          alpha=0.05, s=10,c='green')

ax.scatter(acq_train[~acq_train['target_fraud'].isna()]['lon'], 
            acq_train[~acq_train['target_fraud'].isna()]['lat'],
          alpha=0.05, s=10,c='red')

#ax.scatter(acq_train[~acq_train['target_fraud'].isna()]['lon'], 
#            acq_train[~acq_train['target_fraud'].isna()]['lat'],
#          cmap='Reds', alpha=0.2, s=10,c='r')

ax.grid(alpha=0.2)

plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
plt.grid()
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-75, -35, -35, 5], crs=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
#ax.add_feature(cfeature.RIVERS)


# 2. scatter city data, with color reflecting population
# and size reflecting area
ax.scatter(acq_train['lon'], 
            acq_train['lat'],
          alpha=0.05, s=10,c='green')

ax.scatter(acq_train[acq_train['target_default']==True]['lon'], 
            acq_train[acq_train['target_default']==True]['lat'],
          alpha=0.05, s=10,c='red')

#ax.scatter(acq_train[~acq_train['target_fraud'].isna()]['lon'], 
#            acq_train[~acq_train['target_fraud'].isna()]['lat'],
#          cmap='Reds', alpha=0.2, s=10,c='r')

ax.grid(alpha=0.2)

plt.show()

# %% [markdown]
# ### Horário da ligação

# %% [markdown]
# O gráfico a seguir mostra a distribuição dos horários de ligação para aqueles marcados como fraudadores ou não.
# Enquanto para aqueles não marcados como fraude a distribuição se mantém mais ou menos a mesma, exceto pelo horário de meia-noite, para os casos de fraude há um aumento na madrugada.

# %%
plt.figure(figsize=(10,7))
#plt.grid()
plt.title('Fraude')
sns.countplot(x="application_hour_applied", hue="target_fraud_bin", data=acq_train)

# %% [markdown]
# Vemos a seguir que comportamento semelhante ocorre na inadimplência: o número de pedidos é maior durante a madrugada.

# %%
plt.figure(figsize=(10,7))
#plt.grid()
plt.title('Inadimplência')
sns.countplot(x="application_hour_applied", hue="target_default", data=acq_train)

# %% [markdown]
# ### Perfil do Facebook

# %% [markdown]
# Podemos observar no gráfico a seguir que a razão entre adimplentes e inadimplentes com facebook é maior que a razão daqueles sem, o que pode indicar uma relação entre a rede social e inadimplência.
# Em termos absolutos, o número de inadimplentes com perfil é maior que o número de adimplentes.

# %%
plt.figure(figsize=(10,7))
plt.title('Inadimplência vs Facebook')
sns.countplot(x="facebook_profile", hue="target_default", data=acq_train)

# %%
Comportamento similar ocorre

# %%
plt.figure(figsize=(10,7))
plt.title('Fraude vs Facebook')
sns.countplot(x="target_fraud_bin", hue="facebook_profile", data=acq_train)

# %% [markdown]
# ### Email

# %%
plt.figure(figsize=(10,7))
plt.title('Fraude vs Email')
sns.countplot(x="email", hue="target_default", data=acq_train)

# %% [markdown]
# ## Valores ausentes (*Missing values*)

# %% [markdown]
# Analisaremos aqui os valores ausentes no conjunto de dados de aquisição.
# Para tal, utilizamos a biblioteca `missingno`, que permite a visualização sobre a densidade dos dados ausentes.

# %%
msno.matrix(acq_train,figsize=(20,8),fontsize=14)

# %% [markdown]
#   Algumas colunas, como `last_amount_borrowed` e `last_borrowed_in_months`, possuem diversos valores ausentes
#
#   Além disso, aparentemente há correlação nos valores ausentes para alguns conjuntos de colunas. Por exemplo,
#   * `last_amount_borrowed` e `last_borrowed_in_months`
#   *  `score_1`,
#  `score_2`,
#  `score_3`,
#  `risk_rate`,
#  `reason`,
#  `income`,
#  `state`,
#  `zip`,
#  `channel`,
#  `real_state`,
#  `n_bankruptcies`,
#  `n_defaulted_loans`,
#  `n_accounts`
#
#  Isso sugere que vieram de uma mesma fonte (que não possuía informação para aqueles clientes). A correlação pode ser confirmada no *heatmap* a seguir, onde as duas listas formam *clusters* de cor azul (alta correlação)

# %%
corr_var = ['score_1', 'score_2',
 'score_3',
 'risk_rate',
 'reason',
 'income',
 'state',
 'zip',
 'channel',
 'real_state',
 'n_bankruptcies',
 'n_defaulted_loans',
 'n_accounts',
 'last_amount_borrowed',
 'last_borrowed_in_months']
msno.heatmap(acq_train[corr_var],figsize=(20,8))

# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# ## Manipulação dos dados

# %%
# Applications feitas cedo
early_morning = lambda x: True if 1 <= x <= 7 else False

acq_train['early_morning'] = acq_train['application_hour_applied'].apply(early_morning)
acq_test['early_morning'] = acq_test['application_hour_applied'].apply(early_morning)

# %%
# Email typos

def clean_replace(df, replace_dict):
    for key in replace_dict:
        for entry in replace_dict[key]:
            df[key].replace(entry[0],entry[1],inplace=True)
            

replace_dict = {}
replace_dict['email'] = [['gmaill.com','gmail.com'],['hotmaill.com','hotmail.com']]

clean_replace(acq_train,replace_dict)
clean_replace(acq_test,replace_dict)

# %% [markdown]
# ## Valores ausentes

# %%
def fill_mean(df, col):
    df[col].fillna(df[col].mean(), inplace = True)
    
def fill_zero(df, col):
    df[col].fillna(0, inplace = True)
    
cols_fill_mean = ['score_3', 'risk_rate']
cols_fill_zero = []

for c in cols_fill_mean:
    fill_mean(acq_train,c)
    fill_mean(acq_test,c)
    
for c in cols_fill_zero:
    fill_zero(acq_train,c)
    fill_zero(acq_test,c)

# %%
cols_todrop = []

# %% [markdown]
# # Draft

# %%
var = 'score_1'
#acq_train[acq_train.target_default==False][var].hist(alpha=0.5)
#acq_train[acq_train.target_default==True][var].hist(alpha=0.5)

# %%
target = 'target_default'
#acq_train.dropna(subset=['target_default'],inplace=True)
#acq_train.dropna(subset=[target],inplace=True)
acq_train.fillna(-1, inplace=True)

variables =  continuous  + ['facebook_profile', target]
variables = variables + discrete
#['facebook_profile', 'target_default']
train = acq_train[variables]

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=150, max_depth=8, min_samples_leaf=4, max_features=0.2, n_jobs=-1, random_state=0)
rf.fit(train.drop([target],axis=1), train[target])
features = train.drop([target],axis=1).columns.values
print("----- Training Done -----")
# Out:
# ----- Training Done -----

# %%
def get_feature_importance_df(feature_importances, 
                              column_names, 
                              top_n=25):
    """Get feature importance data frame.
 
    Parameters
    ----------
    feature_importances : numpy ndarray
        Feature importances computed by an ensemble 
            model like random forest or boosting
    column_names : array-like
        Names of the columns in the same order as feature 
            importances
    top_n : integer
        Number of top features
 
    Returns
    -------
    df : a Pandas data frame
 
    """
     
    imp_dict = dict(zip(column_names, 
                        feature_importances))
    top_features = sorted(imp_dict, 
                          key=imp_dict.get, 
                          reverse=True)[0:top_n]
    top_importances = [imp_dict[feature] for feature 
                          in top_features]
    df = pd.DataFrame(data={'feature': top_features, 
                            'importance': top_importances})
    return df

# %%
feature_importance = get_feature_importance_df(rf.feature_importances_, features)

# %%
fig,ax = plt.subplots()
fig.set_size_inches(20,10)
sns.barplot(data=feature_importance[:10],y="feature",x="importance",ax=ax)
ax.set(ylabel='Variable name', xlabel='Importance',title="Variable importances")
# Out:
# [Text(0, 0.5, 'Variable name'),
#  Text(0.5, 0, 'Importance'),
#  Text(0.5, 1.0, 'Variable importances')]

# %%
agg_spend = spend_train.groupby('ids').agg(
    {'credit_line':['min'],
     'month':['max'],
     'spends':['min','max','mean','median', 'sum'],
     'revolving_balance':['min','max','mean','median', 'sum'],
     'card_request':['sum'],
     'minutes_cs':['sum']
    }
    )
agg_spend.columns = ['_'.join(col).strip() for col in agg_spend.columns.values]

# %%
agg_spend.head(10)
# Out:
#                                       credit_line_min  month_max  spends_min  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab            20314         17        0.00
# 0004a450-07bd-c652-8473-4e9dedcff8b8            19973         18      348.00
# 0005967a-2048-6197-a054-30954efe93b1            11728          8       15.38
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df             3117         19        0.00
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9            20000         12      120.40
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65            20000         21        0.00
# 00141481-d30b-2cb1-fefc-dae26098bda6             6704         23      152.93
# 0015133f-867d-7086-a0ff-d50e95c4a615             3686         23       18.50
# 00179c95-2064-da76-3de6-b3d3c40e05cb             8676         25        0.00
# 0017e8b2-29ec-4fa2-5467-77f636830a19            20000         14        0.00
#
#                                       spends_max  spends_mean  spends_median  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab    20268.75  4631.845000       1032.460
# 0004a450-07bd-c652-8473-4e9dedcff8b8    19327.57  9819.764737       9314.420
# 0005967a-2048-6197-a054-30954efe93b1    10703.30  5158.547778       5141.570
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df     3116.41  1778.792500       2149.385
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9    19667.60  7772.272308       5058.400
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65    19940.74  9323.515000       6387.505
# 00141481-d30b-2cb1-fefc-dae26098bda6     6687.12  3350.868750       3570.310
# 0015133f-867d-7086-a0ff-d50e95c4a615     3638.01  1452.810417        798.725
# 00179c95-2064-da76-3de6-b3d3c40e05cb     8675.11  3684.485000       2875.320
# 0017e8b2-29ec-4fa2-5467-77f636830a19    19667.60  6759.986667       5015.800
#
#                                       spends_sum  revolving_balance_min  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab    83373.21                   0.00
# 0004a450-07bd-c652-8473-4e9dedcff8b8   186575.53                   0.00
# 0005967a-2048-6197-a054-30954efe93b1    46426.93                   0.22
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df    35575.85                   0.00
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9   101039.54                   0.00
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65   205117.33                   0.00
# 00141481-d30b-2cb1-fefc-dae26098bda6    80420.85                   0.00
# 0015133f-867d-7086-a0ff-d50e95c4a615    34867.45                   0.00
# 00179c95-2064-da76-3de6-b3d3c40e05cb    95796.61                   0.00
# 0017e8b2-29ec-4fa2-5467-77f636830a19   101399.80                   0.00
#
#                                       revolving_balance_max  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab               19109.42
# 0004a450-07bd-c652-8473-4e9dedcff8b8                6909.14
# 0005967a-2048-6197-a054-30954efe93b1                2706.71
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df                2726.68
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9                9310.31
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65                9310.31
# 00141481-d30b-2cb1-fefc-dae26098bda6                6630.64
# 0015133f-867d-7086-a0ff-d50e95c4a615                1756.49
# 00179c95-2064-da76-3de6-b3d3c40e05cb                7150.82
# 0017e8b2-29ec-4fa2-5467-77f636830a19                9310.31
#
#                                       revolving_balance_mean  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab             2255.217778
# 0004a450-07bd-c652-8473-4e9dedcff8b8             1058.767368
# 0005967a-2048-6197-a054-30954efe93b1              428.543333
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df              539.288500
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9             1315.901538
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65              779.588182
# 00141481-d30b-2cb1-fefc-dae26098bda6             1050.698333
# 0015133f-867d-7086-a0ff-d50e95c4a615              143.741250
# 00179c95-2064-da76-3de6-b3d3c40e05cb              776.567308
# 0017e8b2-29ec-4fa2-5467-77f636830a19             1140.473333
#
#                                       revolving_balance_median  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab                     0.235
# 0004a450-07bd-c652-8473-4e9dedcff8b8                     0.140
# 0005967a-2048-6197-a054-30954efe93b1                    13.200
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df                    11.340
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9                     3.340
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65                     1.610
# 00141481-d30b-2cb1-fefc-dae26098bda6                     0.500
# 0015133f-867d-7086-a0ff-d50e95c4a615                     0.880
# 00179c95-2064-da76-3de6-b3d3c40e05cb                    48.650
# 0017e8b2-29ec-4fa2-5467-77f636830a19                     0.380
#
#                                       revolving_balance_sum  card_request_sum  \
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab               40593.92                 3
# 0004a450-07bd-c652-8473-4e9dedcff8b8               20116.58                 1
# 0005967a-2048-6197-a054-30954efe93b1                3856.89                 1
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df               10785.77                 1
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9               17106.72                 1
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65               17150.94                 3
# 00141481-d30b-2cb1-fefc-dae26098bda6               25216.76                 2
# 0015133f-867d-7086-a0ff-d50e95c4a615                3449.79                 3
# 00179c95-2064-da76-3de6-b3d3c40e05cb               20190.75                 1
# 0017e8b2-29ec-4fa2-5467-77f636830a19               17107.10                 1
#
#                                       minutes_cs_sum
# ids
# 0003da40-123b-031a-63b3-f7c9f18516ab           21.50
# 0004a450-07bd-c652-8473-4e9dedcff8b8           52.71
# 0005967a-2048-6197-a054-30954efe93b1           54.37
# 0009b1d5-f5c3-428e-63dd-39b5f04ad7df           44.08
# 0010b103-a9e4-e08f-ce04-0c65e71a6df9           12.81
# 0010e9b7-c5b2-7944-4ddb-88dc5ad6da65           33.95
# 00141481-d30b-2cb1-fefc-dae26098bda6           26.62
# 0015133f-867d-7086-a0ff-d50e95c4a615          124.72
# 00179c95-2064-da76-3de6-b3d3c40e05cb           75.19
# 0017e8b2-29ec-4fa2-5467-77f636830a19           12.81

# %%
merged = pd.merge(acq_train, agg_spend, on='ids')

# %%
target = 'target_default'
variables =  continuous  + ['facebook_profile', target]
variables = variables + new_var


#['facebook_profile', 'target_default']
train = merged[variables]

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=150, max_depth=10, min_samples_leaf=5, max_features=0.2, n_jobs=-1, random_state=0)
rf.fit(train.drop([target],axis=1), train[target])
features = train.drop([target],axis=1).columns.values
print("----- Training Done -----")
# Out:
# ----- Training Done -----

# %%
feature_importance = get_feature_importance_df(rf.feature_importances_, features)

fig,ax = plt.subplots()
fig.set_size_inches(20,10)
sns.barplot(data=feature_importance[:10],x="feature",y="importance",ax=ax)
ax.set(xlabel='Variable name', ylabel='Importance',title="Variable importances")
# Out:
# [Text(0, 0.5, 'Importance'),
#  Text(0.5, 0, 'Variable name'),
#  Text(0.5, 1.0, 'Variable importances')]
